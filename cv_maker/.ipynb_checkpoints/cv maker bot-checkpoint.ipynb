# %%
#install LaTex
#!pdflatex --version
# !sudo apt-get install -y texlive-base
# !sudo apt-get install -y biblatex
# !sudo apt-get install -y texlive-fonts-recommended
# !sudo apt-get install -y texlive-fonts-extra
# !sudo apt-get install -y texlive-latex-extra
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# texlive-base is already the newest version (2017.20180305-1).
# The following packages were automatically installed and are no longer required:
#   fonts-adf-accanthis fonts-adf-berenis fonts-adf-gillius
#   fonts-adf-universalis fonts-cabin fonts-comfortaa fonts-croscore
#   fonts-ebgaramond fonts-ebgaramond-extra fonts-font-awesome
#   fonts-freefont-otf fonts-freefont-ttf fonts-gfs-artemisia
#   fonts-gfs-complutum fonts-gfs-didot fonts-gfs-neohellenic fonts-gfs-olga
#   fonts-gfs-solomos fonts-go fonts-junicode fonts-lobster fonts-lobstertwo
#   fonts-oflb-asana-math fonts-open-sans fonts-roboto-hinted
#   fonts-sil-gentiumplus fonts-sil-gentiumplus-compact fonts-stix
#   texlive-fonts-extra-links
# Use 'sudo apt autoremove' to remove them.
# 0 upgraded, 0 newly installed, 0 to remove and 74 not upgraded.
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# Package biblatex is not available, but is referred to by another package.
# This may mean that the package is missing, has been obsoleted, or
# is only available from another source
#
# E: Package 'biblatex' has no installation candidate
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# texlive-fonts-recommended is already the newest version (2017.20180305-1).
# The following packages were automatically installed and are no longer required:
#   fonts-adf-accanthis fonts-adf-berenis fonts-adf-gillius
#   fonts-adf-universalis fonts-cabin fonts-comfortaa fonts-croscore
#   fonts-ebgaramond fonts-ebgaramond-extra fonts-font-awesome
#   fonts-freefont-otf fonts-freefont-ttf fonts-gfs-artemisia
#   fonts-gfs-complutum fonts-gfs-didot fonts-gfs-neohellenic fonts-gfs-olga
#   fonts-gfs-solomos fonts-go fonts-junicode fonts-lobster fonts-lobstertwo
#   fonts-oflb-asana-math fonts-open-sans fonts-roboto-hinted
#   fonts-sil-gentiumplus fonts-sil-gentiumplus-compact fonts-stix
#   texlive-fonts-extra-links
# Use 'sudo apt autoremove' to remove them.
# 0 upgraded, 0 newly installed, 0 to remove and 74 not upgraded.
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# Suggested packages:
#   cm-super texlive-fonts-extra-doc
# The following NEW packages will be installed:
#   texlive-fonts-extra
# 0 upgraded, 1 newly installed, 0 to remove and 74 not upgraded.
# Need to get 0 B/354 MB of archives.
# After this operation, 931 MB of additional disk space will be used.
# (Reading database ... 173594 files and directories currently installed.)
# Preparing to unpack .../texlive-fonts-extra_2017.20180305-2_all.deb ...
# Unpacking texlive-fonts-extra (2017.20180305-2) ...
# dpkg: error processing archive /var/cache/apt/archives/texlive-fonts-extra_2017.20180305-2_all.deb (--unpack):
#  cannot copy extracted data for './usr/share/texlive/texmf-dist/fonts/type1/public/fira/FiraSans-Italic.pfb' to '/usr/share/texlive/texmf-dist/fonts/type1/public/fira/FiraSans-Italic.pfb.dpkg-new': failed to write (No space left on device)
# No apport report written because the error message indicates a disk full error
# dpkg-deb: error: paste subprocess was killed by signal (Broken pipe)
# Errors were encountered while processing:
#  /var/cache/apt/archives/texlive-fonts-extra_2017.20180305-2_all.deb
# E: Sub-process /usr/bin/dpkg returned an error code (1)
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# texlive-latex-extra is already the newest version (2017.20180305-2).
# The following packages were automatically installed and are no longer required:
#   fonts-adf-accanthis fonts-adf-berenis fonts-adf-gillius
#   fonts-adf-universalis fonts-cabin fonts-comfortaa fonts-croscore
#   fonts-ebgaramond fonts-ebgaramond-extra fonts-font-awesome
#   fonts-freefont-otf fonts-freefont-ttf fonts-gfs-artemisia
#   fonts-gfs-complutum fonts-gfs-didot fonts-gfs-neohellenic fonts-gfs-olga
#   fonts-gfs-solomos fonts-go fonts-junicode fonts-lobster fonts-lobstertwo
#   fonts-oflb-asana-math fonts-open-sans fonts-roboto-hinted
#   fonts-sil-gentiumplus fonts-sil-gentiumplus-compact fonts-stix
#   texlive-fonts-extra-links
# Use 'sudo apt autoremove' to remove them.
# 0 upgraded, 0 newly installed, 0 to remove and 74 not upgraded.

# %%
import json
import numpy as np 
import pandas as pd
from os import path
import os
import subprocess
import datetime
from pdflatex import PDFLaTeX

# %%
with open('candidate_data/candidates.json') as json_file:
    candidate_data = json.load(json_file)

# %%
# Convert JSON to one dictionary to be able to use code from alessandro
def get_can_dict(can):
    try:
        nationality = can['nationality']['name']
    except:
        nationality = ' '
    try:
        permit = can['residencePermit']['name']
    except:
        permit = ' '
        
    can_dict = {
        'Name': can['firstName'] +" "+ can['lastName'],
        'Nationality': nationality,
        'DOB': datetime.datetime.strptime(can['dateOfBirth'], '%Y-%m-%dT%H:%M:%S.%fZ').strftime("%d.%m.%Y"), 
        'Permit': permit, 
     }

    def get_education(can):
        can_edu = dict()
        i = 1

        # sort list elements by most recent first
        can['education'].sort(key=lambda x: x['startDate'], reverse=True)        
        
        #for edu in can['education']:
        for edu in can['education']:
            university = edu['university']['name']
            if university == "Other":
                university = edu['otherUniversity']

            major = edu['major']['name']
            if major == "Other":
                major = edu['otherMajor']

            startDate = datetime.datetime.strptime(edu['startDate'], '%Y-%m-%dT%H:%M:%S.%fZ').strftime("%m.%Y")
            try:
                endDate = datetime.datetime.strptime(edu['endDate'], '%Y-%m-%dT%H:%M:%S.%fZ').strftime("%m.%Y")
            except:
                endDate = ''
            period = startDate +' - '+ endDate

            # crashes when specialization is null
            if edu['specialization']:
                specialization = edu['specialization']['name']
                if specialization == "Other":
                    specialization = edu['otherSpecialization']
            else:
                specialization = ''

            major = edu['major']['name']
            if major == "Other":
                major = edu['otherMajor']

            temp = {
            'Education'+str(i): university, 
            'Level'+str(i): edu['educationLevel']['name'], 
            'Major'+str(i): major, 
            'Specialization'+str(i): specialization, 
            'Period'+str(i): period, 
            'Grade'+str(i): edu['averageGrade'],
            }
            can_edu.update(temp)   
            i = i+1
        return (i, can_edu)
 

    def get_projects(can):
        can_projects = dict()
        i=1
        
        # beccause education is sorted, projects are kind of sorted as well
        
        for i_edu, edu in enumerate(can['education']):
            for i_pro, project in enumerate(edu['theses']):
                pName  = project['title']
                pType  = project['type']['name']
                pDesc  = project['description']
                pGrade = project['grade']

                temp_dict = {
                    'Project'+str(i): pName,
                    'TypeProject'+str(i): pType,
                    'DescProject'+str(i): pDesc,#.replace('&','\\&'),
                    'GradeProject'+str(i): pGrade
                }
                can_projects.update(temp_dict)
                i = i+1
        return (i, can_projects)


    def get_experiences(can):
        can_exp = dict()
        i = 1
        
        # sort list elements by most recent first
        can['experiences'].sort(key=lambda x: x['startDate'], reverse=True)   
        
        for exp in can['experiences']:
            eTitle = exp['title']
            eEmployer = exp['employer']
            eJobtype = exp['jobType']['name']
            if exp['startDate']:
                startDate = datetime.datetime.strptime(exp['startDate'], '%Y-%m-%dT%H:%M:%S.%fZ').strftime("%m.%Y")
                if exp['endDate']:
                    endDate = datetime.datetime.strptime(exp['endDate'], '%Y-%m-%dT%H:%M:%S.%fZ').strftime("%m.%Y")
                else: endDate=''
            else: startDate = ''
            period = startDate +' - '+ endDate
            eDescription = exp['description']

            temp_dict = {
                'JobTitle'+str(i): eTitle,
                'Position'+str(i): eJobtype,
                'Experience'+str(i): eEmployer,
                'JobPeriod'+str(i): period,
                'JobDescription'+str(i): eDescription#.replace('&','\\&')
            }
            can_exp.update(temp_dict)
            i = i+1
        return (i, can_exp)

    def get_languages(can):
        can_lang = dict()
        i = 1
        try:
            for language in can['languages']:
                temp_dict = {
                    'Lan'+str(i): language['language']['name'],
                    'Lev'+str(i): language['languageLevel']['name']
                }
                can_lang.update(temp_dict)
                i = i+1
        except:
            can_lang = {'Lan'+str(i): 'none', 'Lev'+str(i): 'none'}
        return (i, can_lang)


    def get_skills(can):
        can_skills = dict()
        i = 1
        try:
            for skill in can['itSkills']:
                name = skill['itSkill']['name']
                if name == "Other":
                    name = skill['otherItSkill']

                temp_dict = {
                    'IT'+str(i): name,
                    'LevIT'+str(i): skill['skillLevel']['name'],
                    'DesIT'+str(i): skill['description']#.replace('&','\\&')
                }
                can_skills.update(temp_dict)
                i = i+1
        except:
            can_skills = {'IT'+str(i): 'none',
                    'LevIT'+str(i): 'none',
                    'DesIT'+str(i): 'none'}
        return (i, can_skills)


    def get_jobrequirements(can):
        can_job = dict()
        job = can['jobRequirement']
        startDate = ''
        try:
            startDate = datetime.datetime.strptime(job['startDate'], '%Y-%m-%dT%H:%M:%S.%fZ').strftime("%m.%Y")
            can_job.update(dict({'StartDate': startDate}))
        except:
            pass
        
        try:
            can_job.update({'DesJobType': job['desiredJobType']['name']})
        except:
            pass
        
        try:
            can_job.update({'POW': job['desiredWorkArea']['name']})
        except:
            pass
                                 
        try:
            can_job.update({'TravelAct': job['desiredTravelActivity']['name']})
        except:
            pass
        try:
            can_job.update({'CareerGoal': job['careerGoal']})
        except:
            pass
        try:
            can_job.update({'PositionReq': job['positionRequirements']})
        except:
            pass
        
        i = 1
        try:
            for interest in job['interests']:
                can_job.update(dict({'AOI'+str(i): interest['name']}))
                i = i+1
        except:
            pass
        return (i, can_job)  


    def get_extra(can):
        can_extra = dict()
        i = 1
        
        # sort list elements by most recent first
        can['extracurriculars'].sort(key=lambda x: x['startDate'], reverse=True)  
        
        try:
            for extra in can['extracurriculars']:
                title = extra['title']
                activity = extra['activity']
                desk = extra['description']#.replace('&','\\&')
                if extra['startDate']:
                    startDate = datetime.datetime.strptime(extra['startDate'], '%Y-%m-%dT%H:%M:%S.%fZ').strftime("%m.%Y")
                    if extra['endDate']:
                        endDate = datetime.datetime.strptime(extra['endDate'], '%Y-%m-%dT%H:%M:%S.%fZ').strftime("%m.%Y")
                    else: endDate=''
                else: startDate = ''
                period = startDate +' - '+ endDate

                temp_dict = {
                    'Extra'+str(i): title,
                    'Activity'+str(i): activity,
                    'ExtraPeriod'+str(i): period,
                    'ExtraDes'+str(i): des
                }
                can_extra.update(temp_dict)
                i = i+1
        except:
            pass
        return (i, can_extra)


    def get_aboutme(can):
        can_aboutme = dict()
        i = 1
        try:
            for about in can['miscs']:

                temp_dict = {
                    'About'+str(i): about['topic'],
                    'AboutDes'+str(i): about['description']
                }
                can_aboutme.update(temp_dict)
                i = i+1
        except:
            pass
        return (i, can_aboutme)


    # get all data in clean way
    (edu_counter, can_edu) = get_education(can)
    (pro_counter, can_projects) = get_projects(can)
    (exp_counter, can_exp) = get_experiences(can)
    (lang_counter, can_lang) = get_languages(can)
    (skill_counter, can_skills) = get_skills(can)
    (aoi_counter, can_job) = get_jobrequirements(can)
    (extra_counter, can_extra) = get_extra(can)
    (aboutme_counter, can_aboutme) = get_aboutme(can)

    metadata = {
        'edu_counter': edu_counter,
        'pro_counter': pro_counter,
        'exp_counter': exp_counter,
        'lang_counter': lang_counter,
        'skill_counter': skill_counter,
        'aoi_counter': aoi_counter,
        'extra_counter': extra_counter,
        'aboutme_counter': aboutme_counter
    }
    
    # put all data together in one dictionary
    can_dict.update(can_edu)
    can_dict.update(can_projects)
    can_dict.update(can_exp)
    can_dict.update(can_lang)
    can_dict.update(can_skills)
    can_dict.update(can_job)
    can_dict.update(can_extra)
    can_dict.update(can_aboutme)

    #print(can_dict)
    return (metadata, can_dict)

# %%
# Define helper functions
def save_pdf(file_path, file_name, pdf):
    file_path = file_path +'/'+ file_name + '.pdf'
    
    with open(file_path, 'wb') as f:
     f.write(pdf)
     f.close()
        
        
# returns path of folder directory
def com_folder_path(comId, cv_folder_path):
    
    dir_path = cv_folder_path + comId 
    
    if not path.exists(comId):
        try:
            os.mkdir(dir_path)
        except OSError:
            pass
            #print ("Creation of the directory %s failed" % path)
        else:
            pass
            #print ("Successfully created the directory %s " % path)
    return dir_path


def get_can_values(canId):
    for can in candidate_data['candidates']:
        if can['id'] == canId:
            return can

def get_can_cv(canValues):
    #modify data for alessandro code
    (metadata, can_dict) = get_can_dict(canValues)
    #make tex file
    file_path = make_tex_file(metadata, can_dict)
    #make pdf
    pdfl = PDFLaTeX.from_texfile(file_path)
    pdf, log, completed_process = pdfl.create_pdf()
    return pdf

# %%
# helpers to make the correct tex file for a cv
def prepare_edu_list(j):
    tex_string = ''
    for i in range(1, j): #i is already increased due to the get_can_dict
        tex_string = tex_string +'\\resumeSubheadingW\n      {$Education'+str(i)+'$}{ }\n      {$Level'+str(i)+'$ in $Major'+str(i)+'$, Specialization in $Specialization'+str(i)+'$, $Grade'+str(i)+'$/6}{$Period'+str(i)+'$}\n      '
    return tex_string

def prepare_pro_list(j):
    tex_string = ''
    for i in range(1, j): #i is already increased due to the get_can_dict
        tex_string = tex_string +'\\resumeProjectHeading\n          {\\textbf{$Project'+str(i)+'$}}{$TypeProject'+str(i)+'$}\n          \\resumeItemListStart\n           \\resumeItem{$DescProject'+str(i)+'$}\n        \\resumeItem{Grade: $GradeProject'+str(i)+'$}\n          \\resumeItemListEnd\n      '
    return tex_string
    
def prepare_exp_list(j):
    tex_string = ''
    for i in range(1, j): #i is already increased due to the get_can_dict
        tex_string = tex_string +'\\resumeSubheadingW\n      {$JobTitle'+str(i)+'$}{$Position'+str(i)+'$ position}\n      {$Experience'+str(i)+'$}{$JobPeriod'+str(i)+'$}{}\n      \\resumeItemListStart\n      \\resumeItem{$JobDescription'+str(i)+'$}\n      \\resumeItemListEnd\n    '
    return tex_string

def prepare_lang_list(j):
    tex_string = ''
    for i in range(1, j): #i is already increased due to the get_can_dict
        tex_string = tex_string + '\\resumeProjectHeading{\\textbf{$Lan'+str(i)+'$}}{$Lev'+str(i)+'$}\n'
    return tex_string

def prepare_skill_list(j):
    tex_string = ''
    for i in range(1, j): #i is already increased due to the get_can_dict
        tex_string = tex_string +'\\resumeProjectHeading{\\textbf{$IT'+str(i)+'$}}{$LevIT'+str(i)+'$}\\resumeItemListStart\\resumeItem{$DesIT'+str(i)+'$}\\resumeItemListEnd\n'
    return tex_string

def prepare_aboutme_list(j):
    tex_string = ''
    for i in range(1, j): #i is already increased due to the get_can_dict
        tex_string = tex_string +'\\resumeProjectHeading{\\textbf{$About'+str(i)+'$}}{ }\\resumeItemListStart\\resumeItem{$AboutDes'+str(i)+'$}\\resumeItemListEnd\n'
    return tex_string

def prepare_extra_list(j):
    tex_string = ''
    for i in range(1, j): #i is already increased due to the get_can_dict
        tex_string = tex_string +'\\resumeProjectHeading{\\textbf{$Extra'+str(i)+'$ - $Activity'+str(i)+'$}}{$ExtraPeriod'+str(i)+'$}\\resumeItemListStart\\resumeItem{$ExtraDes'+str(i)+'$}\\resumeItemListEnd\n'
    return tex_string


def prepare_aoi_list(j):
    tex_string = ''
    for i in range(1, j): #i is already increased due to the get_can_dict
        tex_string = tex_string + '$AOI'+str(i)+'$ - '
    return tex_string[:-3]

# %%
def make_tex_file(metadata, dict_template):  

    file_name = '/home/jupyter-jautomation/06_cv_maker/tex_files/Latex_template_'+dict_template['Name']+'.tex'

    # Replace all values that have to be escaped in latex text fields.
    for key, value in dict_template.items():
        #if(str(value).find('&')>=0):
        #    dict_template[key] = value.replace(' &','\\&')
        if(str(value).find('•')>=0):
            dict_template[key] = str(value).replace('•',' ')
        if(str(value).find('#')>=0):
            dict_template[key] = str(value).replace('#','\\#')
        if(str(value).find('$')>=0):
            dict_template[key] = str(value).replace('$','\\$')
        if(str(value).find('%')>=0):
            dict_template[key] = str(value).replace('%','\\%')
        if(str(value).find('_')>=0):
            dict_template[key] = str(value).replace('_','\\_')
        if(str(value).find('{')>=0):
            dict_template[key] = str(value).replace('{','\\{')
        if(str(value).find('}')>=0):
            dict_template[key] = str(value).replace('}','\\}')
        if(str(value).find('[')>=0):
            dict_template[key] = str(value).replace('[','\\[')
        if(str(value).find(']')>=0):
            dict_template[key] = str(value).replace(']','\\]')
        if(str(value).find('ä')>=0):
            dict_template[key] = str(value).replace('ä','\\"a')
        if(str(value).find('ü')>=0):
            dict_template[key] = str(value).replace('ü','\\"u')
        if(str(value).find('ö')>=0):
            dict_template[key] = str(value).replace('ö','\\"o')
        if(str(value).find('é')>=0):
            dict_template[key] = str(value).replace('é',"\\'{e}")
        if(str(value).find('\u000f')>=0):
            dict_template[key] = str(value).replace('\u000f','')
            
    #\u000f
    # Load .tex template to make a new cv from
    with open('Latex_template_ms.tex','r') as file:
        text = file.read()
        
    # Replace tags in .tex file with the correct number of list elements
    text = text.replace('education_list_tag', prepare_edu_list(metadata['edu_counter']))
    text = text.replace('project_list_tag', prepare_pro_list(metadata['pro_counter']))
    text = text.replace('experience_list_tag', prepare_exp_list(metadata['exp_counter']))
    text = text.replace('language_list_tag', prepare_lang_list(metadata['lang_counter']))
    text = text.replace('it_skill_list_tag', prepare_skill_list(metadata['skill_counter']))
    text = text.replace('areas_of_interest_tag', prepare_aoi_list(metadata['aoi_counter']))
    text = text.replace('extracurricular_list_tag', prepare_extra_list(metadata['extra_counter']))
    text = text.replace('things_about_me_list_tag', prepare_aboutme_list(metadata['aboutme_counter']))
    
    # Fill those list elements
    for key, value in dict_template.items():           
            text = text.replace('$'+key+'$', str(value).replace('&','\\&'))
                        
    # Save final cv .tex file   
    with open(file_name, 'w') as output:
        output.write(text)
                        
    #print('.tex created: '+file_name)
    return file_name

# %%
#main, that runs all funcitons and puts all cv's in the respective company folders


with open('candidate_data/candidates.json') as json_file:
    candidate_data = json.load(json_file)
    
with open('candidate_data/interviews.json') as json_file:
    interviews = json.load(json_file)
    
cv_folder_path = '/home/jupyter-jautomation/06_cv_maker/cvs/'
    
def main():
    i=0
    for interview in interviews:
        canId = interview['id']
        comName = interview['company']
        
        folder_path = com_folder_path(comName, cv_folder_path)
        
        canValues = get_can_values(canId) 
        can_name = interview['first_name'] +' '+ interview['last_name']
        try:
            can_cv = get_can_cv(canValues)
            save_pdf(folder_path, can_name, can_cv)
        except:
            print('ERROR in SAVE: '+can_name)
            i=i+1
            
        print(can_name)
    print("total failed:"+str(i))

# %%
main()
# Out:
# Jaco Fuchs
# Severin Meng
# Diego Giovanoli
# Maximilien-Charles Picquet
# Claude Hähni
# Silvan Hinterberger
# Julian Marquard
# Julia Badertscher
# Luca Ferrazzini
# Nicolas Marchal
# Emilie Epiney
# Fabian Alber
# Mina Seiler
# Felix Wegner
# Jérémy  Scheurer
# Christian Wedl
# Marko Palic
# Qais El Okaili
# Sandro Panighetti
# Lukas Bösiger
# Juan Diaz Sada
# Félicité Lordon
# Claudio Ferrari
# Svilen Stefanov
# Claude Hähni
# Andrea Piccione
# Mostafa Lotfy
# Barbara Lesniak
# Alexander Wieland
# Arber Destani
# Kevin Ammann
# Ana Vallejo
# Leo Hofmann
# Tugce Öztürk
# Zhiyang Kathy Yu
# Dominique Heyn
# Maximilien-Charles Picquet
# Flavien Solt
# Stefan Bogdanovic
# Antonia Mateescu
# Farzam Fanitabasi
# Anastasia Sycheva
# Selma Wirth
# Meng-Yuan Yang
# Ivan Tishchenko
# Ahmad Roumie
# Mohit Kapoor
# Marco Adriano Magno
# Ramachandra Kuravi
# Ramy Tanios
# Alessandro Calmanovici
# Franklin Carlson
# Zhiyang Kathy Yu
# Zsolt Kovacs
# Claude Hähni
# Sajan Srikugan
# Simon Müller
# Christian Peters
# Claudio Ferrari
# Jordan Mignan
# Maxim Mattheeuws
# Adrien Merkt
# Tobias Boschung
# Selma Wirth
# Alba Proffe
# Emanuele Giuseppe Esposito
# Jens Hauser
# Miriam Müller
# Lena Egli
# David Deuber
# Martina Grether
# Diego Renner
# Patrick Züst
# Stevan Mihajlovic
# Seraina Roner
# Deluxan Sathananthan
# Flavien Solt
# Niko Torgin Mackinga
# Amray Schwabe
# Francesco Gaetano Fazzi
# Sören Maucher
# ERROR in SAVE: Alexandre Reol
# Alexandre Reol
# Fabian Stuber
# Patrick Amstad
# Pascal Gschwend
# Dario Milano
# Isaac Schroeder
# Nikola Radevic
# Severin Meng
# Zheng Shen
# Benjamin Bossy
# Fabian Stuber
# Marko Palic
# Simon Müller
# Miriam Müller
# Adrien Merkt
# Nazaret Ortiz
# Anton Maksimov
# Bhargav Patel
# Lucrezia Cartocci
# Galina Timofeeva
# Arjun Shah
# Martina Botter
# Eric Burns
# ERROR in SAVE: Prince Tiwari
# Prince Tiwari
# Jan Ulrich Bergsch
# Oliver Brinkmann
# Ioannis Sachinoglou
# Patrick Züst
# Maxim Mattheeuws
# Flavien Solt
# Kai Ott
# Timothy Trovatelli
# Stevan Mihajlovic
# Flavien Solt
# Julian Huwyler
# Patrick Züst
# Maxim Mattheeuws
# Ivan Tishchenko
# Lukas Bösiger
# Marko Palic
# Luca Lavarini
# Luca Pedrelli
# Marvin Breuch
# Chiara Maio
# Gregorio Carughi
# Andrea Piccione
# Yuki Meier
# Tobias Zumsteg
# Edgar Fernandes
# Riccardo Rodighiero
# Fabian Alber
# Bhanuka Abeygoonawardana
# Zhiyang Kathy Yu
# Lena Egli
# Christian Hänsel
# Miriam Müller
# Robert Baumann
# Claude Hähni
# Dan Kluser
# Ivan Tishchenko
# Matthäus Heer
# Lukas Bösiger
# Roman Niggli
# Loris Reiff
# Alessandro Nicolussi
# Derick Sivakumaran
# Lorin Mühlebach
# Aurel Schmid
# Roger Germann
# Normand Overney
# Timothy Trovatelli
# Claudio Ferrari
# Simona Doneva
# total failed:3

# %%
# Creates a ZIP File with all CVs. 
# Jupyter notebook lets you only download files, not directories. 
# This here solves the issue

# !zip -r cvs /home/jupyter-jautomation/06_cv_maker/cvs
# Out:
# updating: home/jupyter-jautomation/06_cv_maker/cvs/ (stored 0%)
# updating: home/jupyter-jautomation/06_cv_maker/cvs/Oliver Wyman/ (stored 0%)
# updating: home/jupyter-jautomation/06_cv_maker/cvs/Oliver Wyman/Lena Egli.pdf (deflated 2%)
# updating: home/jupyter-jautomation/06_cv_maker/cvs/Oliver Wyman/Simon Müller.pdf (deflated 2%)
# updating: home/jupyter-jautomation/06_cv_maker/cvs/Oliver Wyman/Flora Zourek.pdf (deflated 2%)
# updating: home/jupyter-jautomation/06_cv_maker/cvs/Oliver Wyman/Fabian Alber.pdf (deflated 2%)
# updating: home/jupyter-jautomation/06_cv_maker/cvs/Oliver Wyman/Xiang Li.pdf (deflated 2%)
# updating: home/jupyter-jautomation/06_cv_maker/cvs/Oliver Wyman/Matteo Anderegg.pdf (deflated 2%)
# updating: home/jupyter-jautomation/06_cv_maker/cvs/Oliver Wyman/Amray Schwabe.pdf (deflated 2%)
# updating: home/jupyter-jautomation/06_cv_maker/cvs/Oliver Wyman/Emil Krauch.pdf (deflated 2%)
# updating: home/jupyter-jautomation/06_cv_maker/cvs/Unitek Engineering AG/ (stored 0%)
# updating: home/jupyter-jautomation/06_cv_maker/cvs/Unitek Engineering AG/Julian Huwyler.pdf (deflated 2%)
# updating: home/jupyter-jautomation/06_cv_maker/cvs/Unitek Engineering AG/Luca Lavarini.pdf (deflated 2%)
# updating: home/jupyter-jautomation/06_cv_maker/cvs/Unitek Engineering AG/Patrick Züst.pdf (deflated 2%)
# updating: home/jupyter-jautomation/06_cv_maker/cvs/Unitek Engineering AG/Ivan Tishchenko.pdf (deflated 2%)
# updating: home/jupyter-jautomation/06_cv_maker/cvs/Unitek Engineering AG/Maxim Mattheeuws.pdf (deflated 2%)
# updating: home/jupyter-jautomation/06_cv_maker/cvs/Unitek Engineering AG/Lukas Bösiger.pdf (deflated 2%)
# updating: home/jupyter-jautomation/06_cv_maker/cvs/Unitek Engineering AG/Marko Palic.pdf (deflated 2%)
# updating: home/jupyter-jautomation/06_cv_maker/cvs/Unitek Engineering AG/Flavien Solt.pdf (deflated 2%)
# updating: home/jupyter-jautomation/06_cv_maker/cvs/Unitek Engineering AG/Stevan Mihajlovic.pdf (deflated 2%)
# updating: home/jupyter-jautomation/06_cv_maker/cvs/AXA/ (stored 0%)
# updating: home/jupyter-jautomation/06_cv_maker/cvs/AXA/Julian Marquard.pdf (deflated 2%)
# updating: home/jupyter-jautomation/06_cv_maker/cvs/AXA/Claude Hähni.pdf (deflated 2%)
# updating: home/jupyter-jautomation/06_cv_maker/cvs/AXA/David Deuber.pdf (deflated 2%)
# updating: home/jupyter-jautomation/06_cv_maker/cvs/AXA/Sinan Demirci.pdf (deflated 2%)
# updating: home/jupyter-jautomation/06_cv_maker/cvs/AXA/Oliver Brinkmann.pdf (deflated 2%)
# updating: home/jupyter-jautomation/06_cv_maker/cvs/VAT Group AG/ (stored 0%)
# updating: home/jupyter-jautomation/06_cv_maker/cvs/VAT Group AG/Tobias Zumsteg.pdf (deflated 2%)
# updating: home/jupyter-jautomation/06_cv_maker/cvs/VAT Group AG/Andrea Piccione.pdf (deflated 2%)
# updating: home/jupyter-jautomation/06_cv_maker/cvs/VAT Group AG/Marvin Breuch.pdf (deflated 2%)
# updating: home/jupyter-jautomation/06_cv_maker/cvs/VAT Group AG/Lena Egli.pdf (deflated 2%)
# updating: home/jupyter-jautomation/06_cv_maker/cvs/VAT Group AG/Zhiyang Kathy Yu.pdf (deflated 2%)
# updating: home/jupyter-jautomation/06_cv_maker/cvs/VAT Group AG/Bhanuka Abeygoonawardana.pdf (deflated 2%)
# updating: home/jupyter-jautomation/06_cv_maker/cvs/VAT Group AG/Chiara Maio.pdf (deflated 2%)
# updating: home/jupyter-jautomation/06_cv_maker/cvs/VAT Group AG/Riccardo Rodighiero.pdf (deflated 2%)
# updating: home/jupyter-jautomation/06_cv_maker/cvs/VAT Group AG/Miriam Müller.pdf (deflated 2%)
# updating: home/jupyter-jautomation/06_cv_maker/cvs/VAT Group AG/Gregorio Carughi.pdf (deflated 2%)
# updating: home/jupyter-jautomation/06_cv_maker/cvs/VAT Group AG/Fabian Alber.pdf (deflated 2%)
# updating: home/jupyter-jautomation/06_cv_maker/cvs/VAT Group AG/Luca Pedrelli.pdf (deflated 2%)
# updating: home/jupyter-jautomation/06_cv_maker/cvs/VAT Group AG/Yuki Meier.pdf (deflated 2%)
# updating: home/jupyter-jautomation/06_cv_maker/cvs/VAT Group AG/Edgar Fernandes.pdf (deflated 2%)
# updating: home/jupyter-jautomation/06_cv_maker/cvs/VAT Group AG/Robert Baumann.pdf (deflated 2%)
# updating: home/jupyter-jautomation/06_cv_maker/cvs/VAT Group AG/Christian Hänsel.pdf (deflated 2%)
# updating: home/jupyter-jautomation/06_cv_maker/cvs/ti&m / (stored 0%)
# updating: home/jupyter-jautomation/06_cv_maker/cvs/ti&m /Kai Ott.pdf (deflated 2%)
# updating: home/jupyter-jautomation/06_cv_maker/cvs/ti&m /Ioannis Sachinoglou.pdf (deflated 2%)
# updating: home/jupyter-jautomation/06_cv_maker/cvs/ti&m /Patrick Züst.pdf (deflated 2%)
# updating: home/jupyter-jautomation/06_cv_maker/cvs/ti&m /Timothy Trovatelli.pdf (deflated 2%)
# updating: home/jupyter-jautomation/06_cv_maker/cvs/ti&m /Maxim Mattheeuws.pdf (deflated 2%)
# updating: home/jupyter-jautomation/06_cv_maker/cvs/ti&m /Oliver Brinkmann.pdf (deflated 2%)
# updating: home/jupyter-jautomation/06_cv_maker/cvs/ti&m /Flavien Solt.pdf (deflated 2%)
# updating: home/jupyter-jautomation/06_cv_maker/cvs/Lonza AG/ (stored 0%)
# updating: home/jupyter-jautomation/06_cv_maker/cvs/Lonza AG/FRANCESCO FEOLA.pdf (deflated 2%)
# updating: home/jupyter-jautomation/06_cv_maker/cvs/Lonza AG/Yvonne Gombert.pdf (deflated 2%)
# updating: home/jupyter-jautomation/06_cv_maker/cvs/Lonza AG/Gajraj Rathore.pdf (deflated 2%)
# updating: home/jupyter-jautomation/06_cv_maker/cvs/Lonza AG/Concetta Guerra.pdf (deflated 2%)
# updating: home/jupyter-jautomation/06_cv_maker/cvs/Lonza AG/Jan Ulrich Bergsch.pdf (deflated 2%)
# updating: home/jupyter-jautomation/06_cv_maker/cvs/Lonza AG/Gianluca Lombardini.pdf (deflated 2%)
# updating: home/jupyter-jautomation/06_cv_maker/cvs/Lonza AG/Fabia Stich.pdf (deflated 2%)
# updating: home/jupyter-jautomation/06_cv_maker/cvs/Lonza AG/Mina Blagojevic.pdf (deflated 2%)
# updating: home/jupyter-jautomation/06_cv_maker/cvs/Swiss Finance & Property Group/ (stored 0%)
# updating: home/jupyter-jautomation/06_cv_maker/cvs/Swiss Finance & Property Group/Dario Milano.pdf (deflated 2%)
# updating: home/jupyter-jautomation/06_cv_maker/cvs/Swiss Finance & Property Group/Nikola Radevic.pdf (deflated 2%)
# updating: home/jupyter-jautomation/06_cv_maker/cvs/Swiss Finance & Property Group/
pdf (deflated 2%)
# updating: home/jupyter-jautomation/06_cv_maker/cvs/Bard BDI/Franklin Carlson.pdf (deflated 2%)
# updating: home/jupyter-jautomation/06_cv_maker/cvs/Bard BDI/Luca Kiener.pdf (deflated 2%)
# updating: home/jupyter-jautomation/06_cv_maker/cvs/Bard BDI/Jan Zimmermann.pdf (deflated 2%)
# updating: home/jupyter-jautomation/06_cv_maker/cvs/.ipynb_checkpoints/ (stored 0%)
# updating: home/jupyter-jautomation/06_cv_maker/cvs/Stevan Mihajlovic.pdf (deflated 2%)
# updating: home/jupyter-jautomation/06_cv_maker/cvs/Sitrox/ (stored 0%)
# updating: home/jupyter-jautomation/06_cv_maker/cvs/Sitrox/Fabian Landwehr.pdf (deflated 2%)
# updating: home/jupyter-jautomation/06_cv_maker/cvs/Sitrox/Tobias Boschung.pdf (deflated 2%)
# updating: home/jupyter-jautomation/06_cv_maker/cvs/Sitrox/Lukas Bösiger.pdf (deflated 2%)
# updating: home/jupyter-jautomation/06_cv_maker/cvs/Sitrox/Lorin Mühlebach.pdf (deflated 2%)
# updating: home/jupyter-jautomation/06_cv_maker/cvs/Sitrox/Selma Wirth.pdf (deflated 2%)
# updating: home/jupyter-jautomation/06_cv_maker/cvs/Siemens Schweiz AG/ (stored 0%)
# updating: home/jupyter-jautomation/06_cv_maker/cvs/Siemens Schweiz AG/Philippe Mazenauer.pdf (deflated 2%)
# updating: home/jupyter-jautomation/06_cv_maker/cvs/Siemens Schweiz AG/Sandro Panighetti.pdf (deflated 2%)
# updating: home/jupyter-jautomation/06_cv_maker/cvs/Siemens Schweiz AG/Fabian Landwehr.pdf (deflated 2%)
# updating: home/jupyter-jautomation/06_cv_maker/cvs/Siemens Schweiz AG/Sinan Demirci.pdf (deflated 2%)
# updating: home/jupyter-jautomation/06_cv_maker/cvs/Siemens Schweiz AG/Fabian Stuber.pdf (deflated 2%)
# updating: home/jupyter-jautomation/06_cv_maker/cvs/Siemens Schweiz AG/Anton Schirg.pdf (deflated 2%)
# updating: home/jupyter-jautomation/06_cv_maker/cvs/Siemens Schweiz AG/Niko Torgin Mackinga.pdf (deflated 2%)
# updating: home/jupyter-jautomation/06_cv_maker/cvs/Siemens Schweiz AG/Juliette Bromet.pdf (deflated 2%)
# updating: home/jupyter-jautomation/06_cv_maker/cvs/Siemens Schweiz AG/Roman Niggli.pdf (deflated 2%)
# updating: home/jupyter-jautomation/06_cv_maker/cvs/Innovation Process Technology AG/ (stored 0%)
# updating: home/jupyter-jautomation/06_cv_maker/cvs/Innovation Process Technology AG/Julian Huwyler.pdf (deflated 2%)
# updating: home/jupyter-jautomation/06_cv_maker/cvs/Innovation Process Technology AG/Matthäus Heer.pdf (deflated 2%)
# updating: home/jupyter-jautomation/06_cv_maker/cvs/Innovation Process Technology AG/Maximilien-Charles Picquet.pdf (deflated 2%)
# updating: home/jupyter-jautomation/06_cv_maker/cvs/Innovation Process Technology AG/Valentin Anklin.pdf (deflated 2%)
# updating: home/jupyter-jautomation/06_cv_maker/cvs/Innovation Process Technology AG/Luca Lavarini.pdf (deflated 2%)
# updating: home/jupyter-jautomation/06_cv_maker/cvs/Innovation Process Technology AG/Simona Doneva.pdf (deflated 2%)
# updating: home/jupyter-jautomation/06_cv_maker/cvs/Innovation Process Technology AG/Loris Reiff.pdf (deflated 2%)
# updating: home/jupyter-jautomation/06_cv_maker/cvs/Innovation Process Technology AG/Patrick Züst.pdf (deflated 2%)
# updating: home/jupyter-jautomation/06_cv_maker/cvs/Innovation Process Technology AG/Hendrik Züllig.pdf (deflated 2%)
# updating: home/jupyter-jautomation/06_cv_maker/cvs/Innovation Process Technology AG/Manuel Grossmann.pdf (deflated 2%)
# updating: home/jupyter-jautomation/06_cv_maker/cvs/Innovation Process Technology AG/Aris Mukherjee.pdf (deflated 2%)
# updating: home/jupyter-jautomation/06_cv_maker/cvs/Innovation Process Technology AG/Amray Schwabe.pdf (deflated 2%)
# updating: home/jupyter-jautomation/06_cv_maker/cvs/Innovation Process Technology AG/Alessandro Nicolussi.pdf (deflated 2%)
# updating: home/jupyter-jautomation/06_cv_maker/cvs/Innovation Process Technology AG/Julia Badertscher.pdf (deflated 2%)
# updating: home/jupyter-jautomation/06_cv_maker/cvs/Innovation Process Technology AG/Claudio Ferrari.pdf (deflated 2%)
# updating: home/jupyter-jautomation/06_cv_maker/cvs/Innovation Process Technology AG/Dominique Heyn.pdf (deflated 2%)
# updating: home/jupyter-jautomation/06_cv_maker/cvs/Christian Wedl.pdf (deflated 2%)
# updating: home/jupyter-jautomation/06_cv_maker/cvs/PARALLEL Informatik AG/ (stored 0%)
# updating: home/jupyter-jautomation/06_cv_maker/cvs/PARALLEL Informatik AG/Alessandro Calmanovici.pdf (deflated 2%)
# updating: home/jupyter-jautomation/06_cv_maker/cvs/PARALLEL Informatik AG/Leandro Von Krannichfeldt.pdf (deflated 2%)
# updating: home/jupyter-jautomation/06_cv_maker/cvs/PARALLEL Informatik AG/Salvatore Bruno.pdf (deflated 2%)
# updating: home/jupyter-jautomation/06_cv_maker/cvs/PARALLEL Informatik AG/Oliver Brinkmann.pdf (deflated 2%)
# updating: home/jupyter-jautomation/06_cv_maker/cvs/PARALLEL Informatik AG/Stevan Mihajlovic.pdf (deflated 2%)
# updating: home/jupyter-jautomation/06_cv_maker/cvs/PARALLEL Informatik AG/Alexis Müller.pdf (deflated 2%)
# updating: home/jupyter-jautomation/06_cv_maker/cvs/Fabia Stich.pdf (deflated 2%)
# updating: home/jupyter-jautomation/06_cv_maker/cvs/AdNovum Informatik AG/ (stored 0%)
# updating: home/jupyter-jautomation/06_cv_maker/cvs/AdNovum Informatik AG/Andrea Piccione.pdf (deflated 2%)
# updating: home/jupyter-jautomation/06_cv_maker/cvs/AdNovum Informatik AG/Sandro Panighetti.pdf (deflated 2%)
# updating: home/jupyter-jautomation/06_cv_maker/cvs/AdNovum Informatik AG/Claude Hähni.pdf (deflated 2%)
# updating: home/jupyter-jautomation/06_cv_maker/cvs/AdNovum Informatik AG/Qais El Okaili.pdf (deflated 2%)
# updating: home/jupyter-jautomation/06_cv_maker/cvs/AdNovum Informatik AG/Lukas Bösiger.pdf (deflated 2%)
# updating: home/jupyter-jautomation/06_cv_maker/cvs/AdNovum Informatik AG/Juan Diaz Sada.pdf (deflated 2%)
# updating: home/jupyter-jautomation/06_cv_maker/cvs/AdNovum Informatik AG/Félicité Lordon.pdf (deflated 2%)
# updating: home/jupyter-jautomation/06_cv_maker/cvs/AdNovum Informatik AG/Claudio Ferrari.pdf (deflated 2%)
# updating: home/jupyter-jautomation/06_cv_maker/cvs/AdNovum Informatik AG/Svilen Stefanov.pdf (deflated 2%)
# updating: home/jupyter-jautomation/06_cv_maker/cvs/Die Mobiliar/ (stored 0%)
# updating: home/jupyter-jautomation/06_cv_maker/cvs/Die Mobiliar/Munira Kara.pdf (deflated 2%)
# updating: home/jupyter-jautomation/06_cv_maker/cvs/Die Mobiliar/Julian Marquard.pdf (deflated 2%)
# updating: home/jupyter-jautomation/06_cv_maker/cvs/Die Mobiliar/Anastasia Sycheva.pdf (deflated 2%)
# updating: home/jupyter-jautomation/06_cv_maker/cvs/Die Mobiliar/Zhiyang Kathy Yu.pdf (deflated 2%)
# updating: home/jupyter-jautomation/06_cv_maker/cvs/Die Mobiliar/Rashid Khorrami.pdf (deflated 2%)
# updating: home/jupyter-jautomation/06_cv_maker/cvs/Die Mobiliar/David Deuber.pdf (deflated 2%)
# updating: home/jupyter-jautomation/06_cv_maker/cvs/Die Mobiliar/Livia Näf.pdf (deflated 2%)
# updating: home/jupyter-jautomation/06_cv_maker/cvs/Die Mobiliar/Matthias Gey.pdf (deflated 2%)

# %%
#test individual problem children...



cv_folder_path = '/home/jupyter-jautomation/06_cv_maker/cvs/'
com_folder_path = cv_folder_path

#canId = 'f2544dc8-8a7e-422d-8293-fb7c3cabdabd' #matthias
#canId = '1e5e1f41-1121-429a-a0a3-995fafd3fbe4' #alessandro
#canId = 'c455c2a6-84e0-42f1-b801-ea3720ff4cee' #
#canId='f2419789-35d3-4045-bae3-bbeaf172f902'
#canId='ec4acd75-f525-432f-a534-1f88ee2f4327' #vanessa
canId='c6486b9f-b9af-46b2-854c-7574523a418d' #christian wedl
#canId='65117647-1c50-4ce4-89f9-d143db1be877'


canValues = get_can_values(canId)
can_cv = get_can_cv(canValues) 
can_name = canValues['firstName'] +' '+ canValues['lastName']
      
save_pdf(com_folder_path, can_name, can_cv)
print(can_name+'.pdf')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-110-d1fbe560fd51> in <module>
#      16
#      17 canValues = get_can_values(canId)
# ---> 18 can_cv = get_can_cv(canValues)
#      19 can_name = canValues['firstName'] +' '+ canValues['lastName']
#      20
#
# <ipython-input-94-f32f4600f20c> in get_can_cv(canValues)
#      37     #make pdf
#      38     pdfl = PDFLaTeX.from_texfile(file_path)
# ---> 39     pdf, log, completed_process = pdfl.create_pdf()
#      40     return pdf
#      41
#
# /opt/tljh/user/lib/python3.6/site-packages/pdflatex/pdflatex.py in create_pdf(self, keep_pdf_file, keep_log_file, env)
#      75             args = self.get_run_args()
#      76             fp = subprocess.run(args, input=self.latex, env=env, timeout=15, stdout=PIPE, stderr=PIPE)
# ---> 77             with open(os.path.join(td, 'file.pdf'), 'rb') as f:
#      78                 self.pdf = f.read()
#      79             with open(os.path.join(td, 'file.log'), 'rb') as f:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/tmp/tmp7c7vyb8u/file.pdf'
